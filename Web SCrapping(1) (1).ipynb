# %%
import requests
from bs4 import BeautifulSoup
r=requests.get("https://www.gearxpert.in/collections/pulsar-ns-200")
c = r.content
c
# Out:
# b'<!doctype html>\n<html class="js" lang="en">\n  <head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <meta name="theme-color" content="">\n    <link rel="canonical" href="https://www.gearxpert.in/collections/pulsar-ns-200"><link rel="icon" type="image/png" href="//www.gearxpert.in/cdn/shop/files/WhatsApp_Image_2024-10-29_at_5.24.19_PM.png?crop=center&height=32&v=1730204635&width=32"><link rel="preconnect" href="https://fonts.shopifycdn.com" crossorigin><title>\n      Bajaj NS 200 Spare Parts &amp; Accessories - Buy Online with Cash on Delivery\n &ndash; Gearxpert</title>\n\n    \n      <meta name="description" content="Boost your Bajaj NS 200 with high-quality spare parts and accessories. Explore our online store for genuine Bajaj NS 200 spares, including engine components, performance upgrades, and stylish enhancements. Enjoy the ease of cash on delivery for a smo
# ...

# %%
soup=BeautifulSoup(c,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="" name="theme-color"/>
# <link href="https://www.gearxpert.in/collections/pulsar-ns-200" rel="canonical"/><link href="//www.gearxpert.in/cdn/shop/files/WhatsApp_Image_2024-10-29_at_5.24.19_PM.png?crop=center&amp;height=32&amp;v=1730204635&amp;width=32" rel="icon" type="image/png"/><link crossorigin="" href="https://fonts.shopifycdn.com" rel="preconnect"/><title>
#       Bajaj NS 200 Spare Parts &amp; Accessories - Buy Online with Cash on Delivery
#  – Gearxpert</title>
# ...

# %%
all=soup.find_all("div",{"class":"card__information"})
all
# Out:
# [<div class="card__information">
#  <h3 class="card__heading">
#  <a aria-labelledby="StandardCardNoMediaLink-template--16670727176294__product-grid-7418655768678 NoMediaStandardBadge-template--16670727176294__product-grid-7418655768678" class="full-unstyled-link" href="/products/6-led-auxiliary-light-round" id="StandardCardNoMediaLink-template--16670727176294__product-grid-7418655768678">
#                  6 LED Auxiliary Light-Round
#                </a>
#  </h3>
#  </div>,
#  <div class="card__information">
#  <h3 class="card__heading h5" id="title-template--16670727176294__product-grid-7418655768678">
#  <a aria-labelledby="CardLink-template--16670727176294__product-grid-7418655768678 Badge-template--16670727176294__product-grid-7418655768678" class="full-unstyled-link" href="/products/6-led-auxiliary-light-round" id="CardLink-template--16670727176294__product-grid-7418655768678">
#                6 LED Auxiliary Light-Round
#              </a>
#  </h3>
# ...

# %%
len(all)
# Out:
# 48

# %%
all[1]
# Out:
# <div class="card__information">
# <h3 class="card__heading h5" id="title-template--16670727176294__product-grid-7418655768678">
# <a aria-labelledby="CardLink-template--16670727176294__product-grid-7418655768678 Badge-template--16670727176294__product-grid-7418655768678" class="full-unstyled-link" href="/products/6-led-auxiliary-light-round" id="CardLink-template--16670727176294__product-grid-7418655768678">
#               6 LED Auxiliary Light-Round
#             </a>
# </h3>
# <div class="card-information"><span class="caption-large light"></span>
# <div class="price price--on-sale">
# <div class="price__container"><div class="price__regular"><span class="visually-hidden visually-hidden--inline">Regular price</span>
# <span class="price-item price-item--regular">
#             Rs. 1,680.00
#           </span></div>
# <div class="price__sale">
# <span class="visually-hidden visually-hidden--inline">Regular price</span>
# <span>
# <s class="price-item price-item--regular">
#
# ...

# %%
all[2].find_all("a",{"class":"full-unstyled-link"})[0].text
# Out:
# '\n                66Bhp Blue Chain Lube ( 150 ml)\n              '

# %%
all[1].find_all("span",{"class":"price-item price-item--sale price-item--last"})[0].text
# Out:
# '\n          Rs. 1,680.00\n        '

# %%
for item in all:   #to display all price value in the website
    print(all[1].find_all("a",{"class":"full-unstyled-link"})[0].text)
    print(all[1].find_all("span",{"class":"price-item price-item--sale price-item--last"})[0].text)
# Out:
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
#
#               6 LED Auxiliary Light-Round
#
#
#           Rs. 1,680.00
#
# ...

# %%
l=[]
for item in all:   
    d={}
    d["phone_name"]=all[1].find_all("a",{"class":"full-unstyled-link"})[0].text
    d["phone_price"]=all[1].find_all("span",{"class":"price-item price-item--sale price-item--last"})[0].text
    l.append(d)

# %%
l
# Out:
# [{'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
#  {'phone_name': '\n              6 LED Auxiliary Light-Round\n            ',
#   'phone_price': '\n          Rs. 1,680.00\n        '},
# ...

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                                            phone_name  \
# 0   \n              6 LED Auxiliary Light-Round\n ...
# 1   \n              6 LED Auxiliary Light-Round\n ...
# 2   \n              6 LED Auxiliary Light-Round\n ...
# 3   \n              6 LED Auxiliary Light-Round\n ...
# 4   \n              6 LED Auxiliary Light-Round\n ...
# 5   \n              6 LED Auxiliary Light-Round\n ...
# 6   \n              6 LED Auxiliary Light-Round\n ...
# 7   \n              6 LED Auxiliary Light-Round\n ...
# 8   \n              6 LED Auxiliary Light-Round\n ...
# 9   \n              6 LED Auxiliary Light-Round\n ...
# 10  \n              6 LED Auxiliary Light-Round\n ...
# 11  \n              6 LED Auxiliary Light-Round\n ...
# 12  \n              6 LED Auxiliary Light-Round\n ...
# 13  \n              6 LED Auxiliary Light-Round\n ...
# 14  \n              6 LED Auxiliary Light-Round\n ...
# 15  \n              6 LED Auxiliary Light-Round\n ...
# ...
